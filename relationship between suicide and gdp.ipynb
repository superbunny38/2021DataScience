# %%
import pandas as pd
import numpy as np

# %%
s_data = pd.read_csv("suicide.txt", delim_whitespace=True)

# %%
s_data.head(20)
# Out:
#       기간      연령 자살사망자수(명) 자살사망자수(명).1 자살사망자수(명).2 자살률(십만명당) 자살률(십만명당).1  \
# 0     기간      연령         계          남자          여자         계          남자
# 1   2009      합계     2,662       1,631       1,031      26.1        32.2
# 2   2009   0∼14세         9           3           6       1.5         0.9
# 3   2009  15~19세        68          43          25      10.2        12.3
# 4   2009  20~24세       134          62          72      19.6        18.2
# 5   2009  25~29세       248         115         133      25.1        23.5
# 6   2009  30~34세       240         122         118      26.2        26.2
# 7   2009  35~39세       277         169         108      28.6        34.2
# 8   2009  40~44세       227         152          75      26.6        35.6
# 9   2009  45~49세       240         161          79      27.6        37.7
# 10  2009  50~54세       260         188          72      32.5        48.7
# 11  2009  55~59세       197         134          63      34.6        48.4
# ...

# %%
s_data[19:39]
# Out:
#       기간      연령 자살사망자수(명) 자살사망자수(명).1 자살사망자수(명).2 자살률(십만명당) 자살률(십만명당).1  \
# 19  2010      합계     2,668       1,726         942      26.2        34.2
# 20  2010   0∼14세        10           5           5       1.7         1.6
# 21  2010  15~19세        53          31          22       7.9         8.8
# 22  2010  20~24세       121          72          49      18.1        21.5
# 23  2010  25~29세       222         115         107      23.7        24.7
# 24  2010  30~34세       232         131         101      25.3        28.2
# 25  2010  35~39세       263         157         106      27.9        32.6
# 26  2010  40~44세       222         155          67      25.6        35.6
# 27  2010  45~49세       270         186          84      31.8        44.4
# 28  2010  50~54세       269         198          71      32.7        49.9
# 29  2010  55~59세       212         151          61        35        51.6
# 30  2010  60~64세       171         128          43      35.6        55.1
# ...

# %%
total_suicide = s_data[s_data["연령"]=='합계']

# %%
total_suicide.head(15)
# Out:
#        기간  연령 자살사망자수(명) 자살사망자수(명).1 자살사망자수(명).2 자살률(십만명당) 자살률(십만명당).1  \
# 1    2009  합계     2,662       1,631       1,031      26.1        32.2
# 19   2010  합계     2,668       1,726         942      26.2        34.2
# 38   2011  합계     2,722       1,872         850      26.9        37.4
# 56   2012  합계     2,391       1,596         795      23.8        32.1
# 74   2013  합계     2,560       1,764         796      25.6        35.7
# 93   2014  합계     2,467       1,705         762      24.7        34.7
# 112  2015  합계     2,301       1,566         735      23.2        32.1
# 130  2016  합계     2,261       1,567         694        23        32.5
# 148  2017  합계     2,067       1,462         605      21.3        30.7
# 166  2018  합계     2,172       1,475         697      22.5        31.3
# 184  2019  합계     2,151       1,438         713      22.5        30.8
#
#     자살률(십만명당).2
# 1            20
# 19         18.3
# 38         16.6
# 56         15.6
# 74         15.7
# 93         15.1
# ...

# %%
s_columns = total_suicide.columns
s_columns = s_columns.delete(1)
s_columns
# Out:
# Index(['기간', '자살사망자수(명)', '자살사망자수(명).1', '자살사망자수(명).2', '자살률(십만명당)',
#        '자살률(십만명당).1', '자살률(십만명당).2'],
#       dtype='object')

# %%
#콤마 지우기
for i in range(len(s_columns)):
    total_suicide[s_columns[i]] = total_suicide[s_columns[i]].str.replace(',', '')
# Out:
# <ipython-input-56-832418a68dbf>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total_suicide[s_columns[i]] = total_suicide[s_columns[i]].str.replace(',', '')

# %%
#콤마 지우기
for i in range(len(s_columns)):
    total_suicide[s_columns[i]] = pd.to_numeric(total_suicide[s_columns[i]])
# Out:
# <ipython-input-62-fdf2e042eff3>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total_suicide[s_columns[i]] = pd.to_numeric(total_suicide[s_columns[i]])

# %%
total_suicide
# Out:
#        기간  연령  자살사망자수(명)  자살사망자수(명).1  자살사망자수(명).2  자살률(십만명당)  자살률(십만명당).1  \
# 1    2009  합계       2662         1631         1031       26.1         32.2
# 19   2010  합계       2668         1726          942       26.2         34.2
# 38   2011  합계       2722         1872          850       26.9         37.4
# 56   2012  합계       2391         1596          795       23.8         32.1
# 74   2013  합계       2560         1764          796       25.6         35.7
# 93   2014  합계       2467         1705          762       24.7         34.7
# 112  2015  합계       2301         1566          735       23.2         32.1
# 130  2016  합계       2261         1567          694       23.0         32.5
# 148  2017  합계       2067         1462          605       21.3         30.7
# 166  2018  합계       2172         1475          697       22.5         31.3
# 184  2019  합계       2151         1438          713       22.5         30.8
#
#      자살률(십만명당).2
# 1           20.0
# 19          18.3
# ...

# %%
# !pip install xlrd

# %%
total_suicide
# Out:
#        기간  연령  자살사망자수(명)  자살사망자수(명).1  자살사망자수(명).2  자살률(십만명당)  자살률(십만명당).1  \
# 1    2009  합계       2662         1631         1031       26.1         32.2
# 19   2010  합계       2668         1726          942       26.2         34.2
# 38   2011  합계       2722         1872          850       26.9         37.4
# 56   2012  합계       2391         1596          795       23.8         32.1
# 74   2013  합계       2560         1764          796       25.6         35.7
# 93   2014  합계       2467         1705          762       24.7         34.7
# 112  2015  합계       2301         1566          735       23.2         32.1
# 130  2016  합계       2261         1567          694       23.0         32.5
# 148  2017  합계       2067         1462          605       21.3         30.7
# 166  2018  합계       2172         1475          697       22.5         31.3
# 184  2019  합계       2151         1438          713       22.5         30.8
#
#      자살률(십만명당).2
# 1           20.0
# 19          18.3
# ...

# %%
s_cols = ['기간','합계(수)','남자(수)','여자(수)','비율','남자(%)','여자(%)']

# %%
len(s_cols)
# Out:
# 7

# %%
len(total_suicide)
# Out:
# 11

# %%
total_suicide
# Out:
#        기간  합계(수)  남자(수)  여자(수)    비율  남자(%)  여자(%)
# 1    2009   2662   1631   1031  26.1   32.2   20.0
# 19   2010   2668   1726    942  26.2   34.2   18.3
# 38   2011   2722   1872    850  26.9   37.4   16.6
# 56   2012   2391   1596    795  23.8   32.1   15.6
# 74   2013   2560   1764    796  25.6   35.7   15.7
# 93   2014   2467   1705    762  24.7   34.7   15.1
# 112  2015   2301   1566    735  23.2   32.1   14.6
# 130  2016   2261   1567    694  23.0   32.5   13.9
# 148  2017   2067   1462    605  21.3   30.7   12.2
# 166  2018   2172   1475    697  22.5   31.3   14.2
# 184  2019   2151   1438    713  22.5   30.8   14.5

# %%
total_suicide.to_csv('total_suicide.csv')

# %%
# !pip install openpyxl

# %%
data_xls = pd.read_excel('preprocessed_gdp.xlsx')

# %%
gdp = pd.DataFrame(data_xls)

# %%
gdp = gdp[1:]

# %%
gdp = pd.DataFrame(gdp)

# %%
gdp
# Out:
#         Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 1              NaN       1970       1971       1972       1973       1974
# 2     국내총생산(명목GDP)    2,796.6    3,438.0    4,267.7    5,527.3    7,905.0
# 3  경제성장률(실질GDP성장률)       10.1       10.5        7.2       14.9        9.5
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ...  Unnamed: 42  Unnamed: 43  \
# 1       1975       1976       1977       1978  ...         2011         2012
# 2   10,543.6   14,472.8   18,608.1   25,154.5  ...  1,388,937.2  1,440,111.4
# 3        7.8       13.2       12.3       11.0  ...          3.7          2.4
#
#    Unnamed: 44  Unnamed: 45  Unnamed: 46  Unnamed: 47  Unnamed: 48  \
# 1         2013         2014         2015         2016         2017
# 2  1,500,819.1  1,562,928.9  1,658,020.4  1,740,779.6  1,835,698.2
# 3          3.2          3.2          2.8          2.9          3.2
#
#    Unnamed: 49  Unnamed: 50  Unnamed: 51
# 1         2018         2019         2020
# ...

# %%
gdp.columns = ['' for i in range(52)]

# %%
gdp.columns = gdp.iloc[0]

# %%
gdp = gdp.iloc[1:]

# %%
gdp
# Out:
# 1              NaN     1970     1971     1972     1973     1974      1975  \
# 2     국내총생산(명목GDP)  2,796.6  3,438.0  4,267.7  5,527.3  7,905.0  10,543.6
# 3  경제성장률(실질GDP성장률)     10.1     10.5      7.2     14.9      9.5       7.8
#
# 1      1976      1977      1978  ...         2011         2012         2013  \
# 2  14,472.8  18,608.1  25,154.5  ...  1,388,937.2  1,440,111.4  1,500,819.1
# 3      13.2      12.3      11.0  ...          3.7          2.4          3.2
#
# 1         2014         2015         2016         2017         2018  \
# 2  1,562,928.9  1,658,020.4  1,740,779.6  1,835,698.2  1,898,192.6
# 3          3.2          2.8          2.9          3.2          2.9
#
# 1         2019         2020
# 2  1,919,039.9  1,898,192.6
# 3          2.0         -1.0
#
# [2 rows x 52 columns]

# %%
for i in gdp.columns:
    gdp[i] = gdp[i].str.replace(',', '')
# Out:
# <ipython-input-228-eadfe6718dab>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp[i] = gdp[i].str.replace(',', '')

# %%
for i in gdp.columns:
    try:
        gdp[i] = pd.to_numeric(gdp[i])
    except:
        continue
# Out:
# <ipython-input-231-5551cddff6c0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp[i] = pd.to_numeric(gdp[i])

# %%
gdp.columns
# Out:
# Index([   nan, '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020'],
#       dtype='object', name=1)

# %%
real_years = []
for year in years:
    real_years.append(str(year))

# %%
gdp = gdp[real_years]

# %%
gdp
# Out:
# 1       2009       2010       2011       2012       2013       2014  \
# 2  1205347.7  1322611.2  1388937.2  1440111.4  1500819.1  1562928.9
# 3        0.8        6.8        3.7        2.4        3.2        3.2
#
# 1       2015       2016       2017       2018       2019
# 2  1658020.4  1740779.6  1835698.2  1898192.6  1919039.9
# 3        2.8        2.9        3.2        2.9        2.0

# %%
total_suicide
# Out:
#        기간  합계(수)  남자(수)  여자(수)    비율  남자(%)  여자(%)
# 1    2009   2662   1631   1031  26.1   32.2   20.0
# 19   2010   2668   1726    942  26.2   34.2   18.3
# 38   2011   2722   1872    850  26.9   37.4   16.6
# 56   2012   2391   1596    795  23.8   32.1   15.6
# 74   2013   2560   1764    796  25.6   35.7   15.7
# 93   2014   2467   1705    762  24.7   34.7   15.1
# 112  2015   2301   1566    735  23.2   32.1   14.6
# 130  2016   2261   1567    694  23.0   32.5   13.9
# 148  2017   2067   1462    605  21.3   30.7   12.2
# 166  2018   2172   1475    697  22.5   31.3   14.2
# 184  2019   2151   1438    713  22.5   30.8   14.5

# %%
gdp.columns
# Out:
# Index(['2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017',
#        '2018', '2019'],
#       dtype='object', name=1)

# %%
gdp_li = []
for c in gdp.columns:
    gdp_li.append(list(gdp[c]))

# %%
gdp1 = [gdp_li[i][0] for i in range(len(gdp_li))]

# %%
gdp1
# Out:
# [1205347.7,
#  1322611.2,
#  1388937.2,
#  1440111.4,
#  1500819.1,
#  1562928.9,
#  1658020.4,
#  1740779.6,
#  1835698.2,
#  1898192.6,
#  1919039.9]

# %%
gdp2 = [gdp_li[i][1] for i in range(len(gdp_li))]

# %%
gdp2
# Out:
# [0.8, 6.8, 3.7, 2.4, 3.2, 3.2, 2.8, 2.9, 3.2, 2.9, 2.0]

# %%
df_for_graph = pd.DataFrame()

# %%
df_for_graph["total_suicide"] = total_suicide["합계(수)"]

# %%
df_for_graph["GDP"] = gdp1

# %%
df_for_graph["rate"] = gdp2

# %%
df_for_graph
# Out:
#      total_suicide        GDP  rate
# 1             2662  1205347.7   0.8
# 19            2668  1322611.2   6.8
# 38            2722  1388937.2   3.7
# 56            2391  1440111.4   2.4
# 74            2560  1500819.1   3.2
# 93            2467  1562928.9   3.2
# 112           2301  1658020.4   2.8
# 130           2261  1740779.6   2.9
# 148           2067  1835698.2   3.2
# 166           2172  1898192.6   2.9
# 184           2151  1919039.9   2.0

# %%
df_for_graph = df_for_graph.reset_index()

# %%
df_for_graph
# Out:
#     index  total_suicide        GDP  rate
# 0       1           2662  1205347.7   0.8
# 1      19           2668  1322611.2   6.8
# 2      38           2722  1388937.2   3.7
# 3      56           2391  1440111.4   2.4
# 4      74           2560  1500819.1   3.2
# 5      93           2467  1562928.9   3.2
# 6     112           2301  1658020.4   2.8
# 7     130           2261  1740779.6   2.9
# 8     148           2067  1835698.2   3.2
# 9     166           2172  1898192.6   2.9
# 10    184           2151  1919039.9   2.0

# %%
#정규화
# !pip install sklearn
# Out:
# ...
#   Using cached joblib-1.0.1-py3-none-any.whl (303 kB)
# ...
#   Using cached threadpoolctl-2.1.0-py3-none-any.whl (12 kB)
# ...
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1316 sha256=89c3517f740726a639e2f76dee8382e38fff96c0957a4cddf1d15feb40c13c9b
#   Stored in directory: c:\users\lg\appdata\local\pip\cache\wheels\e4\7b\98\b6466d71b8d738a0c547008b9eb39bf8676d1ff6ca4b22af1c
# Successfully built sklearn
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df = df_for_graph.copy()
df[:] = scaler.fit_transform(df[:])

# %%
df.head()
# Out:
#       index  total_suicide       GDP      rate
# 0  0.000000       0.908397  0.000000  0.000000
# 1  0.098361       0.917557  0.164305  1.000000
# 2  0.202186       1.000000  0.257239  0.483333
# 3  0.300546       0.494656  0.328943  0.266667
# 4  0.398907       0.752672  0.414004  0.400000

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15, 10))
x = years
y = total_suicide["합계(수)"]
plt.plot(x,df["total_suicide"],label="n suicide")
plt.plot(x,df["GDP"],label="GDP")
plt.plot(x,df["rate"],label="rate")
plt.xticks(years)
plt.legend()
plt.show()

# %%
#엥
